# %%
from PIL import Image 
from IPython.display import display 
import random
import json

# %%
background= ["Blue", "Military Green", "Light Blue", "Purple", "Sand", "Brown", "Blue-Grey", "Khaki", "Red", "Light Grey", "Grey"]
background_weights = [9.26,9.26,9.26,9.26,9.23,9.21,9.18,9.13,9.03,8.76,8.42]

livery = ["BONES", "RIP", "Video Camera", "None"]
livery_weights = [0.35,0.24,0.09, 99.32]

backbling = ["Shovel", "Chainsaw", "Spear", "Axe", "Magic Staff", "Fire Pitchfork", "Shotgun", "Skateboard", "Arrows", "Dual Katanas", "Gold Shovel", "PB Skateboard", "Angel Wings", "Fire", "Devil Wings", "Diamond Shovel", "Black Angel Wings", "Bloody Axe",       "Scythe", "None"]
backbling_weights = [3.68,2.78,2.67,2.59,2.34,2.32,2.27,2.09,1.99,1.92,1.79,1.71,1.50,1.46,1.31,1.27,1.09,0.91,0.50,63.81]

skeleton = ["Original", "Dark", "Buried", "Drowned", "Zombie", "Half-human", "Bloody", "Gold", "Diamond", "Emerald", "Fire", "Frozen"]
skeleton_weights = [37.57,17.48,10.90,9.79,7.01,6.23,4.37,2.16,1.60,1.39,0.92,0.58]

neck = ["Bead Necklace", "Pearls", "Shiny Necklace", "Cross", "Gold Chain", "Diamond Chain", "NFT Chain", "Stacked Gold Chains", "Stacked Diamond Chains", "None"]
neck_weights = [5.14,4.87,4.74,4.19,3.20,2.49,1.80,1.32,0.98,71.27]

clothing = ["Grey Sweater", "Ripped T-shirt", "Hawaiian Shirt", "Flame Shirt", "Blue Flame Shirt", "Neck Bandana", "Scarf", "Army Vest", "Jacket", "Navy Zip-up Hoodie", "Shell Suit", "Biker Jacket", "Brown Hoodie", "Army Uniform", "Summer Dress", "Caveman Tunic", "Leather Jacket", "Black Suit", "Bandolier", "Hazmat Suit", "Restraint Jacket", "Inmate Jumpsuit", "Bikini", "Mafia Suit", "Hoodie with Puffa", "British Farmer Zip-up", "Checkered Waistcoat", "Fur & Horns", "Winter Coat", "PB Jersey", "Boxing Gloves", "Transparent Raincoat", "PB Hoodie", "Ghillie Suit", "Vampire Cloak", "Service Dress", "Ninja Gi", "Bloody Transparent Raincoat", "Space Suit", "Armed Robot", "Tux", "Napoleon Pirate Jacket", "Red Dress", "Roman Emperor", "Royal Uniform", "None"]
clothing_weights = [3.20,3.05,3.00,2.81,2.76,2.68,2.68,2.52,2.44,2.36,2.36,2.35,2.31,2.29,2.24,2.21,2.16,2.02,2.03,1.87,1.85,1.85,1.83,1.63,1.59,1.54,1.52,1.51,1.42,1.40,1.38,1.22,1.18,1.16,1.03,0.96,0.88,0.85,0.71,0.65,0.62,0.50,0.43,0.38,0.34,22.23]

earrings = ["Silver Studs", "Gold Studs", "Diamond Studs", "Diamond Earrings", "Double Diamond Earrings", "Emerald Studs", "None"]
earrings_weights = [8.32,6.43,5.82,3.36,1.95,0.37,73.75]

facewear_accessories = ["Nosebleed", "Nose Plaster", "Snot", "Gold Teeth", "Diamond Teeth", "Tear Drop Tattoo", "Face Tats", "None"]
facewear_accessories_weights = [5.51,5.34,4.65,3.82,3.73,3.46,2.41,71.08]

headwear_below = ["Plaster", "Stitches", "Brain", "Assassination", "None"]
headwear_below_weights = [5.92,5.49,4.88,0.66,83.05]

facewear = ["Tongue", "Dribble", "Nose Lick", "Wheat", "Lick", "Joint", "Cigar", "War Horn", "Long Tongue", "Pipe", "Lollipop", "Rose", "Apple Juice", "Face Bandana", "Bubble-gum", "Surgical Mask", "Gag Cloth", "Respirator", "Long Beard", "Scruffy Beard", "Face Chain", "Bloody Mouth", "Muzzle Mask", "Combat Knife", "Ninja Mask", "PB Mask", "None"]
facewear_weights = [5.87,4.58,4.53,3.89,3.60,3.18,3.16,3.08,3.00,2.89,2.81,2.73,2.70,2.59,2.53,2.24,2.17,2.11,2.05,2.04,1.97,1.66,1.59,1.52,1.45,1.42,28.64]

eyes = ["Original", "Sleepy", "Chill", "Happy", "Upset", "Tired", "Evil", "X", "Spooked", "Bored", "Swirl", "Loose Eyeball", "Crying", "Love Heart", "Bloody", "Bored Bloody", "Scar", "Flame", "Blue Glowing", "Red Glowing"]
eyes_weights = [20.11,7.91,7.88,7.12,5.46,5.32,4.99,4.90,4.84,4.69,4.63,4.12,4.10,3.83,2.70,2.48,2.19,1.46,0.78,0.49]

eyewear = ["Fake Glasses", "Goggles", "Sport Shades", "Eye Mask", "Spy Glasses", "Spiked", "Flat Shades", "Rave Goggles", "Eye Patch", "Glass Visor", "Shiny Shades", "Ski Goggles", "Shutter Shades", "Transparent", "Purple Tints", "Snorkel", "3D Glasses", "Monocle", "VR Headset", "Blindfold", "Cyberpunk Shades", "Target Finder", "Futuristic Shades", "Laser Optic", "Overhead Goggles", "Aimbot", "X-Ray Goggles" "Laser Beam", "None"]
eyewear_weights = [5.05,4.57,4.39,4.07,3.77,3.74,3.72,3.50,3.37,2.92,2.80,2.68,2.60,2.24,2.19,2.11,2.84,1.95,1.92,1.88,1.48,1.31,1.20,1.03,0.99,0.49,0.11,0.06,31.02]

headwear_above = ["Sweatband", "Head Mirror", "Yellow Beanie", "Coin Purse", "TV Antenna", "Melted Candle", "Bandage", "Sun Hat", "Shuriken", "Gold Laurel Leaf", "Plunger", "Mad Scientist Hair", "Electric Wires", "Biker Helmet", "Cowboy Hat", "Knife Stab", "Spilt Coffee", "Brainwash", "Pirate Hat", "Purple Cap", "Crystal Dagger", "Halo", "Bucket Hat", "Cyberpunk", "Top Knot Bun", "Vietnam Army Helmet", "Mohawk", "Gaming Headset", "Durag", "Short Horns", "Tombstone", "Forward PB Cap", "Messy Hair", "Conical Hat", "Mushrooms", "Army Beret", "Black Angel Horns", "Viking Helmet", "Devil Horns", "Gunshot", "Backwards PB Cap", "Flame Hair", "Snake", "Kings Crown", "Queens Crown", "Waves", "None"]
headwear_above_weights = [3.81,3.57,3.45,3.34,3.20,3.06,3.02,2.92,2.83,2.74,2.59,2.41,2.44,2.16,2.15,1.86,1.85,1.81,1.69,1.65,1.62,1.59,1.54,1.51,1.49,1.46,1.35,1.31,1.28,1.27,1.25,1.20,1.17,1.15,1.13,1.09,0.87,0.86,0.84,0.75,0.74,0.70,0.50,0.46,0.38,0.12,19.82]


# Dictionary variable for each trait. 
# Each trait corresponds to its file name

background_files = {
    "Blue": "",
    "Military Green": "",
    "Light Blue": "",
    "Purple" :"",
    "Sand": "",
    "Brown": "",
    "Blue-Grey":"",
    "Khaki": "", 
    "Red":"",
    "Light Grey":"",
    "Grey":""
}

livery_files = {
    "BONES":"",
    "RIP":"",
    "Video Camera":"",
    "None":""
}

backbling_files ={
    "Shovel":"",
    "Chainsaw":"",
    "Spear":"",
    "Axe":"",
    "Magic Staff":"",
    "Fire Pitchfork":"",
    "Shotgun":"",
    "Skateboard":"",
    "Arrows":"",
    "Dual Katanas":"",
    "Gold Shovel":"",
    "PB Skateboard":"",
    "Angel Wings":"",
    "Fire":"",
    "Devil Wings":"",
    "Diamond Shovel":"",
    "Black Angel Wings":"",
    "Bloody Axe":"",
    "Scythe":"",
    "None":""
}

skeleton_files ={
    "Original": "",
    "Dark": "",
    "Buried": "",
    "Drowned": "",
    "Zombie": "",
    "Half-human": "",
    "Bloody": "",
    "Gold": "",
    "Diamond": "",
    "Emerald": "",
    "Fire": "",
    "Frozen": ""
}

neck_files = {
    "Bead Necklace": "",
    "Pearls": "",
    "Shiny Necklace": "",
    "Cross": "",
    "Gold Chain": "",
    "Diamond Chain": "",
    "NFT Chain": "",
    "Stacked Gold Chains": "",
    "Stacked Diamond Chains": "",
    "None": "",
}

clothing_files = {
    "Grey Sweater": "",
    "Ripped T-shirt": "",
    "Hawaiian Shirt": "",
    "Flame Shirt": "",
    "Blue Flame Shirt": "",
    "Neck Bandana": "",
    "Scarf": "",
    "Army Vest": "",
    "Jacket": "",
    "Navy Zip-up Hoodie": "",
    "Shell Suit": "",
    "Biker Jacket": "",
    "Brown Hoodie": "",
    "Army Uniform": "",
    "Summer Dress": "",
    "Caveman Tunic": "",
    "Leather Jacket": "",
    "Black Suit": "",
    "Bandolier": "",
    "Hazmat Suit": "",
    "Restraint Jacket": "",
    "Inmate Jumpsuit": "",
    "Bikini": "",
    "Mafia Suit": "",
    "Hoodie with Puffa": "",
    "British Farmer Zip-up": "",
    "Checkered Waistcoat": "",
    "Fur & Horns": "",
    "Winter Coat": "",
    "PB Jersey": "",
    "Boxing Gloves": "",
    "Transparent Raincoat": "",
    "PB Hoodie": "",
    "Ghillie Suit": "",
    "Vampire Cloak": "",
    "Service Dress": "",
    "Ninja Gi": "",
    "Bloody Transparent Raincoat": "",
    "Space Suit": "",
    "Armed Robot": "",
    "Tux": "",
    "Napoleon Pirate Jacket": "",
    "Red Dress": "",
    "Roman Emperor": "",
    "Royal Uniform": "",
    "None": ""
}

earring_files = {
    "Silver Studs": "",
    "Gold Studs": "",
    "Diamond Studs": "",
    "Diamond Earrings": "",
    "Double Diamond Earrings": "",
    "Emerald Studs": "",
    "None": ""
}

facewear_files = {
    "Nosebleed": "",
    "Nose Plaster": "",
    "Snot": "",
    "Gold Teeth": "",
    "Diamond Teeth": "",
    "Tear Drop Tattoo": "",
    "Face Tats": "",
    "None": ""
}

headwear_below_files = {
    "Plaster": "", 
    "Stitches": "", 
    "Brain": "", 
    "Assassination": "", 
    "None": ""
}

facewear_files = {
    "Tongue": "", 
    "Dribble": "", 
    "Nose Lick": "", 
    "Wheat": "", 
    "Lick": "", 
    "Joint": "", 
    "Cigar": "", 
    "War Horn": "", 
    "Long Tongue": "", 
    "Pipe": "", 
    "Lollipop": "", 
    "Rose": "", 
    "Apple Juice": "", 
    "Face Bandana": "", 
    "Bubble-gum": "", 
    "Surgical Mask": "", 
    "Gag Cloth": "", 
    "Respirator": "", 
    "Long Beard": "", 
    "Scruffy Beard": "", 
    "Face Chain": "", 
    "Bloody Mouth": "", 
    "Muzzle Mask": "", 
    "Combat Knife": "", 
    "Ninja Mask": "", 
    "PB Mask": "", 
    "None": ""
}

eyes_files = {
    "Original": "", 
    "Sleepy": "", 
    "Chill": "", 
    "Happy": "", 
    "Upset": "", 
    "Tired": "", 
    "Evil": "", 
    "X": "", 
    "Spooked": "", 
    "Bored": "", 
    "Swirl": "", 
    "Loose Eyeball": "", 
    "Crying": "", 
    "Love Heart": "", 
    "Bloody": "", 
    "Bored Bloody": "", 
    "Scar": "", 
    "Flame": "", 
    "Blue Glowing": "", 
    "Red Glowing": "" 
}

eyewear_files = {
    "Fake Glasses": "", 
    "Goggles": "", 
    "Sport Shades": "", 
    "Eye Mask": "", 
    "Spy Glasses": "", 
    "Spiked": "", 
    "Flat Shades": "", 
    "Rave Goggles": "", 
    "Eye Patch": "", 
    "Glass Visor": "", 
    "Shiny Shades": "", 
    "Ski Goggles": "", 
    "Shutter Shades": "", 
    "Transparent": "", 
    "Purple Tints": "", 
    "Snorkel": "", 
    "3D Glasses": "", 
    "Monocle": "", 
    "VR Headset": "", 
    "Blindfold": "", 
    "Cyberpunk Shades": "", 
    "Target Finder": "", 
    "Futuristic Shades": "", 
    "Laser Optic": "", 
    "Overhead Goggles": "", 
    "Aimbot": "", 
    "X-Ray Goggles": "", 
    "Laser Beam": "", 
    "None": ""
}

headwear_above_files = {
    "Sweatband": "", 
    "Head Mirror": "", 
    "Yellow Beanie": "", 
    "Coin Purse": "", 
    "TV Antenna": "", 
    "Melted Candle": "", 
    "Bandage": "", 
    "Sun Hat": "", 
    "Shuriken": "", 
    "Gold Laurel Leaf": "", 
    "Plunger": "", 
    "Mad Scientist Hair": "", 
    "Electric Wires": "", 
    "Biker Helmet": "", 
    "Cowboy Hat": "", 
    "Knife Stab": "", 
    "Spilt Coffee": "", 
    "Brainwash": "", 
    "Pirate Hat": "", 
    "Purple Cap": "", 
    "Crystal Dagger": "", 
    "Halo": "", 
    "Bucket Hat": "", 
    "Cyberpunk": "", 
    "Top Knot Bun": "", 
    "Vietnam Army Helmet": "", 
    "Mohawk": "", 
    "Gaming Headset": "", 
    "Durag": "", 
    "Short Horns": "", 
    "Tombstone": "", 
    "Forward PB Cap": "", 
    "Messy Hair": "", 
    "Conical Hat": "", 
    "Mushrooms": "", 
    "Army Beret": "", 
    "Black Angel Horns": "", 
    "Viking Helmet": "", 
    "Devil Horns": "", 
    "Gunshot": "", 
    "Backwards PB Cap": "", 
    "Flame Hair": "", 
    "Snake": "", 
    "Kings Crown": "", 
    "Queens Crown": "", 
    "Waves": "", 
    "None": "" 
}

# %%
## Generate Traits

TOTAL_IMAGES = 10000 # Number of random unique images we want to generate

all_images = [] 

# A recursive function to generate unique image combinations
def create_new_image():
    
    new_image = {} 

    # For each trait category, select a random trait based on the weightings
    new_image ["Background"] = random.choices(background, background_weights)[0]
    new_image ["Livery"] = random.choices(livery, livery_weights)[0]
    new_image ["Backbling"] = random.choices(backbling, backbling_weights)[0]
    new_image ["Skeleton"] = random.choices(skeleton, skeleton_weights)[0]
    new_image ["Neck"] = random.choices(neck, neck_weights)[0]
    new_image ["Clothing"] = random.choices(clothing, clothing_weights)[0]
    new_image ["Earring"] = random.choices(earrings, earrings_weights)[0]
    new_image ["Facewear Accessories"] = random.choices(facewear_accessories, facewear_accessories_weights)[0]
    new_image ["Headwear Below"] = random.choices(headwear_below, headwear_below_weights)[0]
    new_image ["Facewear"] = random.choices(facewear, facewear_weights)[0]
    new_image ["Eyes"] = random.choices(eyes, eyes_weights)[0]
    new_image ["Eyewear"] = random.choices(eyewear, eyewear_weights)[0]
    new_image ["Headwear Above"] = random.choices(headwear_above, headwear_above_weights)[0]
    

    if new_image in all_images:
        return create_new_image()
    else:
        return new_image
    
    
# Generate the unique combinations based on trait weightings
for i in range(TOTAL_IMAGES): 
    
    new_trait_image = create_new_image()
    
    all_images.append(new_trait_image)

# %%
# Returns true if all images are unique
def all_images_unique(all_images):
    seen = list()
    return not any(i in seen or seen.append(i) for i in all_images)

print("Are all images unique?", all_images_unique(all_images))
# Out:
# Are all images unique? True

# %%
# Add token Id to each image
i = 0
for item in all_images:
    item["tokenId"] = i
    i = i + 1

# %%
#print(all_images)

# %%
# Get Trait Counts
background_count = {}
for item in background:
    background_count[item] = 0
    
livery_count = {}
for item in livery:
    livery_count[item] = 0

backbling_count = {}
for item in backbling:
    backbling_count[item] = 0

neck_count = {}
for item in neck:
    neck_count[item] = 0

skeleton_count = {}
for item in skeleton:
    skeleton_count[item] = 0

clothing_count = {}
for item in clothing:
    clothing_count[item] = 0

earrings_count = {}
for item in earrings:
    earrings_count[item] = 0

facewear_accessories_count = {}
for item in facewear_accessories:
    facewear_accessories_count[item] = 0

headwear_below_count = {}
for item in headwear_below:
    headwear_below_count[item] = 0

facewear_count = {}
for item in facewear:
    facewear_count[item] = 0

eyes_count = {}
for item in eyes:
    eyes_count[item] = 0

eyewear_count = {}
for item in eyewear:
    eyewear_count[item] = 0

headwear_above_count = {}
for item in headwear_above:
    headwear_above_count[item] = 0

for image in all_images:
    background_count[image["Background"]] += 1
    livery_count[image["Livery"]] += 1
    backbling_count[image["Backbling"]] += 1
    neck_count[image["Neck"]] += 1
    skeleton_count[image["Skeleton"]] += 1
    clothing_count[image["Clothing"]] += 1
    earrings_count[image["Earring"]] += 1
    facewear_accessories_count[image["Facewear Accessories"]] += 1
    headwear_below_count[image["Headwear Below"]] += 1
    facewear_count[image["Facewear"]] += 1
    eyes_count[image["Eyes"]] += 1
    eyewear_count[image["Eyewear"]] += 1
    headwear_above_count[image["Headwear Above"]] += 1
    
    
print(background_count)
print(livery_count)
print(backbling_count)
print(neck_count)
print(skeleton_count)
print(clothing_count)
print(earrings_count)
print(facewear_accessories_count)
print(headwear_below_count)
print(facewear_count)
print(eyes_count)
print(eyewear_count)
print(headwear_above_count)
# Out:
# {'Bespin': 398, 'Daylight': 1147, 'Rain': 803, 'Shooting Star': 510, 'Starry Night': 845, 'Sunshine': 1143, 'Sunset': 1154}
# {'Prickly Pear': 342, 'Snake Plant': 809, 'Zebra Cactus': 881, 'Parodia': 1065, 'Golden Barrel': 1380, 'Saguaro': 1231, 'Echeveria': 292}
# {'Teal': 496, 'Sunset': 199, 'Coral': 257, 'Ocean': 266, 'Red': 996, 'Lime': 806, 'Blues': 692, 'Sour': 339, 'Yellow': 1046, 'Purple': 903}
# {'Bee': 918, 'Worm': 1044, 'Butterfly': 475, 'Ladybug': 624, 'Spider': 297, 'Beetle': 419, 'Dragonfly': 241, 'None': 1982}
# {'Cute': 1668, 'Side-eye': 1108, 'Pretty': 1144, 'Scared': 774, 'Kiss': 712, 'Grin': 350, 'Derpy': 244}
# {'Dinosaur': 168, 'Gnome': 153, 'Alarm Clock': 807, 'Alien': 244, 'Mushroom': 348, 'Sandcastle': 767, 'Radio': 616, 'None': 2897}
# {'String of Pearls': 386, 'String of Nickles': 891, 'String of Hearts': 68, 'English Ivy': 123, 'Hindu Rope': 572, "Burro's Tail": 347, "Lamb's Tail": 250, 'None': 3363}

# %%
#### Generate Metadata for all Traits 
METADATA_FILE_NAME = './metadata/all-traits.json'; 
with open(METADATA_FILE_NAME, 'w') as outfile:
    json.dump(all_images, outfile, indent=4)

# %%
  
    
#### Generate Images    
for item in all_images:

    im1 = Image.open(f'./trait-layers/backgrounds/{background_files[item["Background"]]}.png').convert('RGBA')
    im2 = Image.open(f'./trait-layers/liverys/{livery_files[item["Livery"]]}.png').convert('RGBA')
    im3 = Image.open(f'./trait-layers/backblings/{backbling_files[item["Backbling"]]}.png').convert('RGBA')
    im4 = Image.open(f'./trait-layers/necks/{neck_files[item["Neck"]]}.png').convert('RGBA')
    im5 = Image.open(f'./trait-layers/skeletons/{skeleton_files[item["Skeleton"]]}.png').convert('RGBA')
    im6 = Image.open(f'./trait-layers/clothings/{clothing_files[item["Clothing"]]}.png').convert('RGBA')
    im7 = Image.open(f'./trait-layers/buddies/{earring_files[item["Earring"]]}.png').convert('RGBA')

    #Create each composite
    com1 = Image.alpha_composite(im1, im2)
    com2 = Image.alpha_composite(com1, im3)
    com3 = Image.alpha_composite(com2, im4)
    com4 = Image.alpha_composite(com3, im5)
    com5 = Image.alpha_composite(com4, im6)
    com6 = Image.alpha_composite(com5, im7)

#########################################


    #Convert to RGB
    rgb_im = com6.convert('RGB')
    file_name = str(item["tokenId"]) + ".png"
    rgb_im.save("./images/" + file_name)

# %%
#### Generate Metadata for each Image    

#f = open('./metadata/all-traits.json',) 
#data = json.load(f)
#
#
## base uri is https://ipfs.io/ipfs/ #directory uri
#IMAGES_BASE_URI = "ipfs://"
#PROJECT_NAME = "Pocket Bones"
#
#def getAttribute(key, value):
#    return {
#        "trait_type": key,
#        "value": value
#    }
#for i in data:
#    token_id = i['tokenId']
#    token = {
#        "image": IMAGES_BASE_URI + str(token_id) + '.png',
#        "tokenId": token_id,
#        "name": PROJECT_NAME + ' ' + str(token_id),
#        "attributes": []
#    }
#    token["attributes"].append(getAttribute("Background", i["Background"]))
#    token["attributes"].append(getAttribute("Livery", i["Livery"]))
#    token["attributes"].append(getAttribute("Neck", i["Neck"]))
#    token["attributes"].append(getAttribute("Clothing", i["Clothing"]))
#    token["attributes"].append(getAttribute("Earring", i["Earring"]))
#    token["attributes"].append(getAttribute("Backbling", i["Backbling"]))
#    token["attributes"].append(getAttribute("Skeleton", i["Skeleton"]))
#
#    with open('./metadata/' + str(token_id), 'w') as outfile:
#        json.dump(token, outfile, indent=4)
#f.close()

# %%
# ADD IPFS HASH TO JSON, ASSUMING YOU HAVE A JSON FILE LIKE THIS:

#'''
#{
#"QmeBdP4zNCEEbqm9Y2UZb6skg8RVLkgDzQ2ojgZf71cBc8": "0",
#"QmWBLUBgVJfSGQDHDR5LNyccRatnsBDjUwtCv7DpiQ9N11": "1",
#"QmejsSBzpYyeG8SgyZejrCxrABS4t7e1fjysstBJkNr6Bg": "10",
#"QmSVRL6dGQVzUXXy6Q4dPa3mebS755Xeek1b9ZejMyfY8L": "11",
#"QmZYBEBbR3SBA56UVSdcGyRKQqceQ2s35paoGrtuixqP6F": "12",
#...
#}
#
#'''
#with open("./metadata/all-traits.json", 'r') as f:
#    traits = json.load(f)
#
#with open("./metadata/hashes.json", 'r') as f:
#    hashes = json.load(f)
#    
#for key in hashes:
#    i = int(hashes[key])
#    print(key, ":", hashes[key])
#    traits[i]["imageIPFS"] = key 
#
#with open('./metadata/finaltraits.json', 'w') as outfile:
#    json.dump(traits, outfile, indent=4)
